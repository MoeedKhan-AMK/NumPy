# %% [markdown]
# # MARKDOWN USEFUL COMMANDS
#
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# ### Bold Text:
# (** bold **)
#
# ### Italic Text:
# (* italic *)
#
# ### Bullet List:
# - Item 1
# - Item 2
# - Item 3
#
# ### Numbered List:
# 1. Step one
# 2. Step two
# 3. Step three
#
# ### Code (inline):
# ` your_code_here `
#
# ### Code Block:
# ```python
# print("Hello World")
# ```
#
# ### Horizontal Line:
# ---
#
# ### Link:
# ** [ Name of Website ]( link of website )**
#
# ### Image:
# ! [ Alt Text ]( image url )
